# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# BTC vs ETH Volatility Modelling (GARCH)\n",
    "\n",
    "This notebook demonstrates how to compare **Bitcoin (BTC)** and **Ethereum (ETH)** volatility using GARCH(1,1)."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "from src.btcvol.config import Config\n",
    "from src.btcvol.data import load_returns_panel\n",
    "from src.btcvol.models import fit_garch11\n",
    "from src.btcvol.plotting import plot_compare, plot_scatter"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Set Config"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "cfg = Config(\n",
    "    start=\"2018-01-01\",\n",
    "    end=\"2024-12-31\",\n",
    "    tickers=(\"BTC-USD\", \"ETH-USD\"),\n",
    "    dist=\"t\",\n",
    "    outdir=\"results\"\n",
    ")\n",
    "cfg"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Load data and compute log returns"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "rets = load_returns_panel(cfg.tickers, cfg.start, cfg.end)\n",
    "rets.tail()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Fit GARCH(1,1) for BTC & ETH"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "btc_res = fit_garch11(rets[\"BTC-USD\"], dist=cfg.dist)\n",
    "eth_res = fit_garch11(rets[\"ETH-USD\"], dist=cfg.dist)\n",
    "\n",
    "btc_res.summary()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Plot conditional volatility"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "btc_sigma = btc_res.conditional_volatility.rename(\"BTC σ\")\n",
    "eth_sigma = eth_res.conditional_volatility.rename(\"ETH σ\")\n",
    "\n",
    "plot_compare({\"BTC\": btc_sigma, \"ETH\": eth_sigma}, \"BTC vs ETH Volatility (GARCH(1,1))\", show=True)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5. Correlation analysis"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "sigma_df = pd.concat([btc_sigma, eth_sigma], axis=1).dropna()\n",
    "sigma_df.corr()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 6. Scatter plot of volatilities"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "plot_scatter(sigma_df[\"BTC σ\"], sigma_df[\"ETH σ\"], \"BTC vs ETH Volatility Scatter\", show=True)"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# BTC vs ETH Volatility Modelling (GARCH)\n",
#       8     "\n",
#       9     "This notebook demonstrates how to compare **Bitcoin (BTC)** and **Ethereum (ETH)** volatility using GARCH(1,1)."
#      10    ]
#      11   },
#      12   {
#      13    "cell_type": "code",
# ---> 14    "execution_count": null,
#      15    "metadata": {},
#      16    "outputs": [],
#      17    "source": [
#      18     "import pandas as pd\n",
#      19     "import matplotlib.pyplot as plt\n",
#      20     "from src.btcvol.config import Config\n",
#      21     "from src.btcvol.data import load_returns_panel\n",
#      22     "from src.btcvol.models import fit_garch11\n",
#      23     "from src.btcvol.plotting import plot_compare, plot_scatter"
#      24    ]
#      25   },
#      26   {
#      27    "cell_type": "markdown",
#      28    "metadata": {},
#      29    "source": [
#      30     "## 1. Set Config"
#      31    ]
#      32   },
#      33   {
#      34    "cell_type": "code",
#      35    "execution_count": null,
#      36    "metadata": {},
#      37    "outputs": [],
#      38    "source": [
#      39     "cfg = Config(\n",
#      40     "    start=\"2018-01-01\",\n",
#      41     "    end=\"2024-12-31\",\n",
#      42     "    tickers=(\"BTC-USD\", \"ETH-USD\"),\n",
#      43     "    dist=\"t\",\n",
#      44     "    outdir=\"results\"\n",
#      45     ")\n",
#      46     "cfg"
#      47    ]
#      48   },
#      49   {
#      50    "cell_type": "markdown",
#      51    "metadata": {},
#      52    "source": [
#      53     "## 2. Load data and compute log returns"
#      54    ]
#      55   },
#      56   {
#      57    "cell_type": "code",
#      58    "execution_count": null,
#      59    "metadata": {},
#      60    "outputs": [],
#      61    "source": [
#      62     "rets = load_returns_panel(cfg.tickers, cfg.start, cfg.end)\n",
#      63     "rets.tail()"
#      64    ]
#      65   },
#      66   {
#      67    "cell_type": "markdown",
#      68    "metadata": {},
#      69    "source": [
#      70     "## 3. Fit GARCH(1,1) for BTC & ETH"
#      71    ]
#      72   },
#      73   {
#      74    "cell_type": "code",
#      75    "execution_count": null,
#      76    "metadata": {},
#      77    "outputs": [],
#      78    "source": [
#      79     "btc_res = fit_garch11(rets[\"BTC-USD\"], dist=cfg.dist)\n",
#      80     "eth_res = fit_garch11(rets[\"ETH-USD\"], dist=cfg.dist)\n",
#      81     "\n",
#      82     "btc_res.summary()"
#      83    ]
#      84   },
#      85   {
#      86    "cell_type": "markdown",
#      87    "metadata": {},
#      88    "source": [
#      89     "## 4. Plot conditional volatility"
#      90    ]
#      91   },
#      92   {
#      93    "cell_type": "code",
#      94    "execution_count": null,
#      95    "metadata": {},
#      96    "outputs": [],
#      97    "source": [
#      98     "btc_sigma = btc_res.conditional_volatility.rename(\"BTC σ\")\n",
#      99     "eth_sigma = eth_res.conditional_volatility.rename(\"ETH σ\")\n",
#     100     "\n",
#     101     "plot_compare({\"BTC\": btc_sigma, \"ETH\": eth_sigma}, \"BTC vs ETH Volatility (GARCH(1,1))\", show=True)"
#     102    ]
#     103   },
#     104   {
#     105    "cell_type": "markdown",
#     106    "metadata": {},
#     107    "source": [
#     108     "## 5. Correlation analysis"
#     109    ]
#     110   },
#     111   {
#     112    "cell_type": "code",
#     113    "execution_count": null,
#     114    "metadata": {},
#     115    "outputs": [],
#     116    "source": [
#     117     "sigma_df = pd.concat([btc_sigma, eth_sigma], axis=1).dropna()\n",
#     118     "sigma_df.corr()"
#     119    ]
#     120   },
#     121   {
#     122    "cell_type": "markdown",
#     123    "metadata": {},
#     124    "source": [
#     125     "## 6. Scatter plot of volatilities"
#     126    ]
#     127   },
#     128   {
#     129    "cell_type": "code",
#     130    "execution_count": null,
#     131    "metadata": {},
#     132    "outputs": [],
#     133    "source": [
#     134     "plot_scatter(sigma_df[\"BTC σ\"], sigma_df[\"ETH σ\"], \"BTC vs ETH Volatility Scatter\", show=True)"
#     135    ]
#     136   }
#     137  ],
#     138  "metadata": {
#     139   "kernelspec": {
#     140    "display_name": "Python 3",
#     141    "language": "python",
#     142    "name": "python3"
#     143   },
#     144   "language_info": {
#     145    "name": "python",
#     146    "version": "3.11"
#     147   }
#     148  },
#     149  "nbformat": 4,
#     150  "nbformat_minor": 5
#     151 }
#
# NameError: name 'null' is not defined
